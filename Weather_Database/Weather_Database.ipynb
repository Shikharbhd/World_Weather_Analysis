# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack lat_lngs zip object to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
#6.2.6: Get the City Weather Data

import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create an empty list to hold the weather data.
city_data=[]
# Print the begining of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#create counters
record_count=1
set_count=1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | noumea
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | capinopolis
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | port hedland
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kharp
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | lishu
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | san carlos
# Processing Record 14 of Set 1 | gijon
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | vanavara
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | manggar
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | sorong
# Processing Record 28 of Set 1 | grand gaube
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | port hawkesbury
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | shouguang
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | strezhevoy
# Processing Record 38 of Set 1 | motril
# Processing Record 39 of Set 1 | cap-aux-meules
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | puqi
# Processing Record 42 of Set 1 | festus
# Processing Record 43 of Set 1 | sibolga
# Processing Record 44 of Set 1 | singaraja
# Processing Record 45 of Set 1 | broome
# Processing Record 46 of Set 1 | baker city
# Processing Record 47 of Set 1 | iskateley
# Processing Record 48 of Set 1 | kelvington
# Processing Record 49 of Set 1 | ahuimanu
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | faranah
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | inirida
# Processing Record 5 of Set 2 | fatehabad
# Processing Record 6 of Set 2 | bereda
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | fort frances
# Processing Record 11 of Set 2 | najran
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | knysna
# Processing Record 14 of Set 2 | flinders
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | krivopolyanye
# City not found. Skipping...
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | rusape
# Processing Record 19 of Set 2 | santa cruz cabralia
# Processing Record 20 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 2 | ust-ilimsk
# Processing Record 22 of Set 2 | padang
# Processing Record 23 of Set 2 | yar-sale
# Processing Record 24 of Set 2 | brae
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | chimbote
# Processing Record 27 of Set 2 | komsomolskiy
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | timmins
# Processing Record 35 of Set 2 | chabahar
# Processing Record 36 of Set 2 | saurimo
# Processing Record 37 of Set 2 | port blair
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | nakhon phanom
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | naryan-mar
# Processing Record 43 of Set 2 | porto real
# Processing Record 44 of Set 2 | porto murtinho
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | esperance
# Processing Record 48 of Set 2 | we
# City not found. Skipping...
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | vao
# Processing Record 1 of Set 3 | olinda
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | canico
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | los llanos de aridane
# Processing Record 8 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | polis
# Processing Record 11 of Set 3 | kieta
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | puerto penasco
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | batagay-alyta
# Processing Record 18 of Set 3 | labuhan
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | tungor
# Processing Record 22 of Set 3 | agadir
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | wanaka
# Processing Record 25 of Set 3 | constitucion
# Processing Record 26 of Set 3 | awjilah
# Processing Record 27 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | malinovskiy
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | itarema
# Processing Record 33 of Set 3 | sorland
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | kyra
# Processing Record 36 of Set 3 | berdigestyakh
# Processing Record 37 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | gorontalo
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | selenginsk
# Processing Record 42 of Set 3 | evensk
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | lagoa da canoa
# Processing Record 45 of Set 3 | umarkot
# Processing Record 46 of Set 3 | ostrovnoy
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | piacabucu
# Processing Record 50 of Set 3 | bizhbulyak
# Processing Record 1 of Set 4 | te anau
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | ruian
# City not found. Skipping...
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | soyo
# Processing Record 6 of Set 4 | suleja
# Processing Record 7 of Set 4 | khandyga
# Processing Record 8 of Set 4 | burica
# City not found. Skipping...
# Processing Record 9 of Set 4 | yebaishou
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | songea
# Processing Record 12 of Set 4 | boa vista
# Processing Record 13 of Set 4 | arman
# Processing Record 14 of Set 4 | mujiayingzi
# Processing Record 15 of Set 4 | harsin
# Processing Record 16 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 4 | trairi
# Processing Record 18 of Set 4 | ilulissat
# Processing Record 19 of Set 4 | egvekinot
# Processing Record 20 of Set 4 | torquay
# Processing Record 21 of Set 4 | srednekolymsk
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | mackay
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | calama
# Processing Record 26 of Set 4 | coxim
# Processing Record 27 of Set 4 | pauini
# Processing Record 28 of Set 4 | halifax
# Processing Record 29 of Set 4 | eresos
# Processing Record 30 of Set 4 | gernsbach
# Processing Record 31 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 4 | xilokastron
# City not found. Skipping...
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | celestun
# Processing Record 35 of Set 4 | canoa
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | mykhaylivka
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | sabha
# Processing Record 40 of Set 4 | kanniyakumari
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | madimba
# Processing Record 43 of Set 4 | senigallia
# Processing Record 44 of Set 4 | stornoway
# Processing Record 45 of Set 4 | vanimo
# Processing Record 46 of Set 4 | ulaanbaatar
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | avallon
# Processing Record 49 of Set 4 | dwarka
# Processing Record 50 of Set 4 | bayanday
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | saint andrews
# Processing Record 5 of Set 5 | gat
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | la solana
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | straseni
# Processing Record 10 of Set 5 | nurobod
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | belyy yar
# Processing Record 13 of Set 5 | garcia
# Processing Record 14 of Set 5 | bairnsdale
# Processing Record 15 of Set 5 | kolokani
# Processing Record 16 of Set 5 | lazaro cardenas
# Processing Record 17 of Set 5 | atar
# Processing Record 18 of Set 5 | kodinsk
# Processing Record 19 of Set 5 | dingle
# Processing Record 20 of Set 5 | beyneu
# Processing Record 21 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 5 | matadi
# Processing Record 23 of Set 5 | fare
# Processing Record 24 of Set 5 | hofn
# Processing Record 25 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 5 | awbari
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | vila
# Processing Record 29 of Set 5 | raudeberg
# Processing Record 30 of Set 5 | sarangani
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | wewak
# Processing Record 33 of Set 5 | nacala
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | solok
# Processing Record 37 of Set 5 | ketchikan
# Processing Record 38 of Set 5 | balykshi
# Processing Record 39 of Set 5 | nassau
# Processing Record 40 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 5 | thohoyandou
# Processing Record 42 of Set 5 | hami
# Processing Record 43 of Set 5 | berlevag
# Processing Record 44 of Set 5 | dospat
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | mumford
# Processing Record 47 of Set 5 | kendari
# Processing Record 48 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 5 | elizabeth city
# Processing Record 50 of Set 5 | arraial do cabo
# Processing Record 1 of Set 6 | lai
# Processing Record 2 of Set 6 | heihe
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | south lake tahoe
# Processing Record 5 of Set 6 | prince rupert
# Processing Record 6 of Set 6 | port elizabeth
# Processing Record 7 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 6 | tongren
# Processing Record 9 of Set 6 | trybukhivtsi
# Processing Record 10 of Set 6 | sola
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | codrington
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | zamania
# Processing Record 16 of Set 6 | guiberoua
# Processing Record 17 of Set 6 | badnawar
# Processing Record 18 of Set 6 | helong
# Processing Record 19 of Set 6 | mollendo
# Processing Record 20 of Set 6 | bijar
# Processing Record 21 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 6 | collie
# Processing Record 23 of Set 6 | penzance
# Processing Record 24 of Set 6 | bay saint louis
# Processing Record 25 of Set 6 | kuhestan
# City not found. Skipping...
# Processing Record 26 of Set 6 | tautira
# Processing Record 27 of Set 6 | acajutla
# Processing Record 28 of Set 6 | kaduqli
# Processing Record 29 of Set 6 | kabalo
# Processing Record 30 of Set 6 | ayan
# Processing Record 31 of Set 6 | angoche
# Processing Record 32 of Set 6 | tanggu
# Processing Record 33 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 34 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 6 | puerto baquerizo moreno
# Processing Record 36 of Set 6 | aykhal
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | camacha
# Processing Record 40 of Set 6 | verkhnevilyuysk
# Processing Record 41 of Set 6 | tazovskiy
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | saint-augustin
# Processing Record 44 of Set 6 | karratha
# Processing Record 45 of Set 6 | indramayu
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | verkhoyansk
# Processing Record 48 of Set 6 | horsham
# Processing Record 49 of Set 6 | geraldton
# Processing Record 50 of Set 6 | port augusta
# Processing Record 1 of Set 7 | amapa
# Processing Record 2 of Set 7 | marapanim
# Processing Record 3 of Set 7 | baghdad
# Processing Record 4 of Set 7 | peace river
# Processing Record 5 of Set 7 | kysyl-syr
# Processing Record 6 of Set 7 | kizukuri
# Processing Record 7 of Set 7 | noshiro
# Processing Record 8 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 9 of Set 7 | huzhou
# Processing Record 10 of Set 7 | ponta do sol
# Processing Record 11 of Set 7 | kijang
# Processing Record 12 of Set 7 | buraydah
# Processing Record 13 of Set 7 | khani
# Processing Record 14 of Set 7 | katsuura
# Processing Record 15 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 7 | kirovskiy
# Processing Record 17 of Set 7 | new norfolk
# Processing Record 18 of Set 7 | bacolod
# Processing Record 19 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 7 | kaitangata
# Processing Record 21 of Set 7 | warmbad
# Processing Record 22 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 7 | pochutla
# Processing Record 24 of Set 7 | bogale
# Processing Record 25 of Set 7 | calvinia
# Processing Record 26 of Set 7 | kano
# Processing Record 27 of Set 7 | clinton
# Processing Record 28 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 7 | simbahan
# Processing Record 30 of Set 7 | sisimiut
# Processing Record 31 of Set 7 | irbil
# Processing Record 32 of Set 7 | phan thiet
# Processing Record 33 of Set 7 | quelimane
# Processing Record 34 of Set 7 | namatanai
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | walvis bay
# Processing Record 37 of Set 7 | srandakan
# Processing Record 38 of Set 7 | anadyr
# Processing Record 39 of Set 7 | gulu
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 42 of Set 7 | bredasdorp
# Processing Record 43 of Set 7 | nishihara
# Processing Record 44 of Set 7 | taber
# Processing Record 45 of Set 7 | imbituba
# Processing Record 46 of Set 7 | rayon
# Processing Record 47 of Set 7 | zhicheng
# Processing Record 48 of Set 7 | urengoy
# Processing Record 49 of Set 7 | mitu
# Processing Record 50 of Set 7 | belen
# Processing Record 1 of Set 8 | kota bahru
# Processing Record 2 of Set 8 | cayenne
# Processing Record 3 of Set 8 | yining
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | biak
# Processing Record 6 of Set 8 | adrar
# Processing Record 7 of Set 8 | saint-paul
# Processing Record 8 of Set 8 | auki
# Processing Record 9 of Set 8 | jawhar
# Processing Record 10 of Set 8 | husavik
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | sao filipe
# Processing Record 13 of Set 8 | abha
# Processing Record 14 of Set 8 | velyka mykhaylivka
# Processing Record 15 of Set 8 | grado
# Processing Record 16 of Set 8 | haines junction
# Processing Record 17 of Set 8 | kuldur
# Processing Record 18 of Set 8 | kaduna
# Processing Record 19 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 8 | pankrushikha
# Processing Record 21 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 8 | sayyan
# Processing Record 23 of Set 8 | clyde river
# Processing Record 24 of Set 8 | tadine
# Processing Record 25 of Set 8 | makhachkala
# Processing Record 26 of Set 8 | antalaha
# Processing Record 27 of Set 8 | almaznyy
# Processing Record 28 of Set 8 | salinopolis
# Processing Record 29 of Set 8 | narsaq
# Processing Record 30 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 31 of Set 8 | ahipara
# Processing Record 32 of Set 8 | popondetta
# Processing Record 33 of Set 8 | mamakan
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | fukue
# Processing Record 36 of Set 8 | margate
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | banda aceh
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | nelson bay
# Processing Record 41 of Set 8 | zhigansk
# Processing Record 42 of Set 8 | wangkui
# Processing Record 43 of Set 8 | am timan
# Processing Record 44 of Set 8 | kunigal
# Processing Record 45 of Set 8 | sattahip
# Processing Record 46 of Set 8 | lesnoy
# Processing Record 47 of Set 8 | tirumullaivasal
# Processing Record 48 of Set 8 | porto walter
# Processing Record 49 of Set 8 | tias
# Processing Record 50 of Set 8 | balikpapan
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | yamada
# Processing Record 3 of Set 9 | kenai
# Processing Record 4 of Set 9 | pirovskoye
# Processing Record 5 of Set 9 | norman wells
# Processing Record 6 of Set 9 | bandar-e lengeh
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | wilmington
# Processing Record 9 of Set 9 | la baneza
# Processing Record 10 of Set 9 | gwadar
# Processing Record 11 of Set 9 | cabiraoan
# Processing Record 12 of Set 9 | katherine
# Processing Record 13 of Set 9 | korla
# Processing Record 14 of Set 9 | grindavik
# Processing Record 15 of Set 9 | oriximina
# Processing Record 16 of Set 9 | khuzdar
# Processing Record 17 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | jeremie
# Processing Record 20 of Set 9 | rawson
# Processing Record 21 of Set 9 | tahoua
# Processing Record 22 of Set 9 | souillac
# Processing Record 23 of Set 9 | ormara
# Processing Record 24 of Set 9 | aginskoye
# Processing Record 25 of Set 9 | kadaya
# Processing Record 26 of Set 9 | kargasok
# Processing Record 27 of Set 9 | poum
# Processing Record 28 of Set 9 | belokurikha
# Processing Record 29 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 9 | polson
# Processing Record 31 of Set 9 | salym
# Processing Record 32 of Set 9 | paamiut
# Processing Record 33 of Set 9 | santa lucia cotzumalguapa
# Processing Record 34 of Set 9 | marabba
# Processing Record 35 of Set 9 | bichena
# Processing Record 36 of Set 9 | luganville
# Processing Record 37 of Set 9 | sistranda
# Processing Record 38 of Set 9 | villazon
# Processing Record 39 of Set 9 | lucapa
# Processing Record 40 of Set 9 | hailar
# Processing Record 41 of Set 9 | jam sahib
# Processing Record 42 of Set 9 | teruel
# Processing Record 43 of Set 9 | saint george
# Processing Record 44 of Set 9 | vredendal
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | tateyama
# Processing Record 47 of Set 9 | nome
# Processing Record 48 of Set 9 | klaksvik
# Processing Record 49 of Set 9 | calabozo
# Processing Record 50 of Set 9 | medicine hat
# Processing Record 1 of Set 10 | pasighat
# Processing Record 2 of Set 10 | shebalino
# Processing Record 3 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 10 | la palma
# Processing Record 5 of Set 10 | yerbogachen
# Processing Record 6 of Set 10 | sao joao da barra
# Processing Record 7 of Set 10 | kaura namoda
# Processing Record 8 of Set 10 | nadym
# Processing Record 9 of Set 10 | benguela
# Processing Record 10 of Set 10 | alice springs
# Processing Record 11 of Set 10 | kashary
# Processing Record 12 of Set 10 | libreville
# Processing Record 13 of Set 10 | guaira
# Processing Record 14 of Set 10 | price
# Processing Record 15 of Set 10 | rodrigues alves
# Processing Record 16 of Set 10 | winneba
# Processing Record 17 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 18 of Set 10 | twentynine palms
# Processing Record 19 of Set 10 | semey
# Processing Record 20 of Set 10 | tual
# Processing Record 21 of Set 10 | wangqing
# Processing Record 22 of Set 10 | kalmar
# Processing Record 23 of Set 10 | timberlake
# Processing Record 24 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 25 of Set 10 | havre-saint-pierre
# Processing Record 26 of Set 10 | kamenka
# Processing Record 27 of Set 10 | shache
# Processing Record 28 of Set 10 | yinchuan
# Processing Record 29 of Set 10 | hervey bay
# Processing Record 30 of Set 10 | freeport
# Processing Record 31 of Set 10 | mosquera
# Processing Record 32 of Set 10 | peniche
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | bonavista
# Processing Record 35 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 10 | manzanillo
# Processing Record 37 of Set 10 | cintalapa
# Processing Record 38 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 39 of Set 10 | marsaxlokk
# Processing Record 40 of Set 10 | zabol
# Processing Record 41 of Set 10 | chemax
# Processing Record 42 of Set 10 | adamovka
# Processing Record 43 of Set 10 | tynda
# Processing Record 44 of Set 10 | aras
# Processing Record 45 of Set 10 | lasa
# Processing Record 46 of Set 10 | isla vista
# Processing Record 47 of Set 10 | mering
# Processing Record 48 of Set 10 | nha trang
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | haverfordwest
# Processing Record 1 of Set 11 | ingham
# Processing Record 2 of Set 11 | krasnyy chikoy
# Processing Record 3 of Set 11 | orizona
# Processing Record 4 of Set 11 | rincon
# Processing Record 5 of Set 11 | miri
# Processing Record 6 of Set 11 | zhuhai
# Processing Record 7 of Set 11 | kumburgaz
# Processing Record 8 of Set 11 | vila do maio
# Processing Record 9 of Set 11 | college
# Processing Record 10 of Set 11 | dabat
# Processing Record 11 of Set 11 | marquette
# Processing Record 12 of Set 11 | beziers
# Processing Record 13 of Set 11 | mangrol
# Processing Record 14 of Set 11 | gamba
# Processing Record 15 of Set 11 | henties bay
# Processing Record 16 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 11 | pangnirtung
# Processing Record 19 of Set 11 | kiruna
# Processing Record 20 of Set 11 | pacific grove
# Processing Record 21 of Set 11 | san lazaro
# Processing Record 22 of Set 11 | kutum
# Processing Record 23 of Set 11 | kahului
# Processing Record 24 of Set 11 | celendin
# Processing Record 25 of Set 11 | necochea
# Processing Record 26 of Set 11 | medvezhyegorsk
# Processing Record 27 of Set 11 | tierralta
# Processing Record 28 of Set 11 | oskarshamn
# Processing Record 29 of Set 11 | nichinan
# Processing Record 30 of Set 11 | sortavala
# Processing Record 31 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 11 | cheyenne
# Processing Record 33 of Set 11 | sinnamary
# Processing Record 34 of Set 11 | goundam
# Processing Record 35 of Set 11 | sadat
# Processing Record 36 of Set 11 | qeshm
# Processing Record 37 of Set 11 | bella vista
# Processing Record 38 of Set 11 | tiarei
# Processing Record 39 of Set 11 | godre
# City not found. Skipping...
# Processing Record 40 of Set 11 | havoysund
# Processing Record 41 of Set 11 | lahat
# Processing Record 42 of Set 11 | malko tarnovo
# Processing Record 43 of Set 11 | maumere
# Processing Record 44 of Set 11 | tel aviv-yafo
# Processing Record 45 of Set 11 | san jeronimo
# Processing Record 46 of Set 11 | chicama
# Processing Record 47 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 11 | motygino
# Processing Record 49 of Set 11 | nanzhou
# Processing Record 50 of Set 11 | talnakh
# Processing Record 1 of Set 12 | storforshei
# Processing Record 2 of Set 12 | bengkulu
# Processing Record 3 of Set 12 | novi pazar
# Processing Record 4 of Set 12 | santo tomas
# Processing Record 5 of Set 12 | wa
# City not found. Skipping...
# Processing Record 6 of Set 12 | acapulco
# Processing Record 7 of Set 12 | palora
# Processing Record 8 of Set 12 | chumikan
# Processing Record 9 of Set 12 | narasannapeta
# Processing Record 10 of Set 12 | mount isa
# Processing Record 11 of Set 12 | russell
# Processing Record 12 of Set 12 | nedjo
# Processing Record 13 of Set 12 | akyab
# Processing Record 14 of Set 12 | bandarbeyla
# Processing Record 15 of Set 12 | minsk
# Processing Record 16 of Set 12 | rochegda
# Processing Record 17 of Set 12 | nuuk
# Processing Record 18 of Set 12 | holme
# Processing Record 19 of Set 12 | santa rosa
# Processing Record 20 of Set 12 | saint-denis
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | hualmay
# Processing Record 23 of Set 12 | gidam
# Processing Record 24 of Set 12 | gruia
# Processing Record 25 of Set 12 | valleyview
# Processing Record 26 of Set 12 | mme
# City not found. Skipping...
# Processing Record 27 of Set 12 | progreso
# Processing Record 28 of Set 12 | bonnyville
# Processing Record 29 of Set 12 | rock sound
# Processing Record 30 of Set 12 | ewa beach
# Processing Record 31 of Set 12 | houston
# Processing Record 32 of Set 12 | solwezi
# Processing Record 33 of Set 12 | orbetello
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | nizwa
# Processing Record 36 of Set 12 | ucluelet
# Processing Record 37 of Set 12 | baruun-urt
# Processing Record 38 of Set 12 | uhlove
# Processing Record 39 of Set 12 | pervomayskiy
# Processing Record 40 of Set 12 | usinsk
# Processing Record 41 of Set 12 | diamantino
# Processing Record 42 of Set 12 | kaka
# Processing Record 43 of Set 12 | riyadh
# Processing Record 44 of Set 12 | luderitz
# Processing Record 45 of Set 12 | mahmudia
# Processing Record 46 of Set 12 | jurm
# Processing Record 47 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 12 | bay roberts
# Processing Record 49 of Set 12 | alamogordo
# Processing Record 50 of Set 12 | harper
# Processing Record 1 of Set 13 | ilhabela
# Processing Record 2 of Set 13 | tafresh
# Processing Record 3 of Set 13 | meulaboh
# Processing Record 4 of Set 13 | aioi
# Processing Record 5 of Set 13 | paralia
# Processing Record 6 of Set 13 | fort nelson
# Processing Record 7 of Set 13 | ngunguru
# Processing Record 8 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 13 | ixtapa
# Processing Record 10 of Set 13 | praia da vitoria
# Processing Record 11 of Set 13 | shelburne
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | akureyri
# Processing Record 14 of Set 13 | suez
# Processing Record 15 of Set 13 | omboue
# Processing Record 16 of Set 13 | asau
# Processing Record 17 of Set 13 | barmer
# Processing Record 18 of Set 13 | simao
# Processing Record 19 of Set 13 | ipixuna
# Processing Record 20 of Set 13 | koungou
# Processing Record 21 of Set 13 | aklavik
# Processing Record 22 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 13 | rantepao
# Processing Record 25 of Set 13 | napier
# Processing Record 26 of Set 13 | igrim
# Processing Record 27 of Set 13 | limbang
# Processing Record 28 of Set 13 | honiara
# Processing Record 29 of Set 13 | peleduy
# Processing Record 30 of Set 13 | mamlyutka
# Processing Record 31 of Set 13 | zeya
# Processing Record 32 of Set 13 | portland
# Processing Record 33 of Set 13 | polyarnyy
# Processing Record 34 of Set 13 | northam
# Processing Record 35 of Set 13 | ushumun
# Processing Record 36 of Set 13 | lompoc
# Processing Record 37 of Set 13 | moree
# Processing Record 38 of Set 13 | pervomayskoye
# Processing Record 39 of Set 13 | north platte
# Processing Record 40 of Set 13 | kaeo
# Processing Record 41 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 13 | boca do acre
# Processing Record 43 of Set 13 | makakilo city
# Processing Record 44 of Set 13 | guaruja
# Processing Record 45 of Set 13 | atasu
# Processing Record 46 of Set 13 | amazar
# Processing Record 47 of Set 13 | asadabad
# Processing Record 48 of Set 13 | charleville-mezieres
# Processing Record 49 of Set 13 | aberdeen
# Processing Record 50 of Set 13 | whitehorse
# Processing Record 1 of Set 14 | burla
# Processing Record 2 of Set 14 | nautla
# Processing Record 3 of Set 14 | valparaiso
# Processing Record 4 of Set 14 | westport
# Processing Record 5 of Set 14 | birao
# Processing Record 6 of Set 14 | port hardy
# Processing Record 7 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 14 | mezen
# Processing Record 9 of Set 14 | bhanvad
# Processing Record 10 of Set 14 | mayo
# Processing Record 11 of Set 14 | panjab
# Processing Record 12 of Set 14 | kilindoni
# Processing Record 13 of Set 14 | bilma
# Processing Record 14 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 15 of Set 14 | lata
# Processing Record 16 of Set 14 | kalengwa
# Processing Record 17 of Set 14 | oranjemund
# Processing Record 18 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 14 | prokopyevsk
# Processing Record 20 of Set 14 | marawi
# Processing Record 21 of Set 14 | uniao
# Processing Record 22 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 14 | beringovskiy
# Processing Record 24 of Set 14 | flin flon
# Processing Record 25 of Set 14 | burgeo
# Processing Record 26 of Set 14 | campoverde
# Processing Record 27 of Set 14 | batemans bay
# Processing Record 28 of Set 14 | lake city
# Processing Record 29 of Set 14 | talcahuano
# Processing Record 30 of Set 14 | shimoda
# Processing Record 31 of Set 14 | port macquarie
# Processing Record 32 of Set 14 | erenhot
# Processing Record 33 of Set 14 | the valley
# Processing Record 34 of Set 14 | leshukonskoye
# Processing Record 35 of Set 14 | armizonskoye
# Processing Record 36 of Set 14 | tucuman
# Processing Record 37 of Set 14 | priargunsk
# Processing Record 38 of Set 14 | santa cruz del sur
# Processing Record 39 of Set 14 | thinadhoo
# Processing Record 40 of Set 14 | san andres
# Processing Record 41 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 14 | argir
# Processing Record 44 of Set 14 | mackenzie
# Processing Record 45 of Set 14 | bathsheba
# Processing Record 46 of Set 14 | colquechaca
# Processing Record 47 of Set 14 | plymouth
# Processing Record 48 of Set 14 | umm kaddadah
# Processing Record 49 of Set 14 | bondo
# Processing Record 50 of Set 14 | ndele
# Processing Record 1 of Set 15 | talaya
# Processing Record 2 of Set 15 | marzuq
# Processing Record 3 of Set 15 | xining
# Processing Record 4 of Set 15 | inverell
# Processing Record 5 of Set 15 | zavodouspenskoye
# Processing Record 6 of Set 15 | manubul
# Processing Record 7 of Set 15 | guerrero negro
# Processing Record 8 of Set 15 | qasigiannguit
# Processing Record 9 of Set 15 | kashi
# Processing Record 10 of Set 15 | faya
# Processing Record 11 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 15 | grand-lahou
# Processing Record 13 of Set 15 | parrita
# Processing Record 14 of Set 15 | nova kakhovka
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | fougamou
# Processing Record 17 of Set 15 | taltal
# Processing Record 18 of Set 15 | barra do bugres
# Processing Record 19 of Set 15 | state college
# Processing Record 20 of Set 15 | tymovskoye
# Processing Record 21 of Set 15 | yumen
# Processing Record 22 of Set 15 | okha
# Processing Record 23 of Set 15 | ciamis
# Processing Record 24 of Set 15 | jizan
# Processing Record 25 of Set 15 | sechura
# Processing Record 26 of Set 15 | san juan
# Processing Record 27 of Set 15 | pemba
# Processing Record 28 of Set 15 | guamal
# Processing Record 29 of Set 15 | kangaatsiaq
# Processing Record 30 of Set 15 | marsh harbour
# Processing Record 31 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 32 of Set 15 | zabid
# Processing Record 33 of Set 15 | tupik
# Processing Record 34 of Set 15 | udachnyy
# Processing Record 35 of Set 15 | almajiu
# City not found. Skipping...
# Processing Record 36 of Set 15 | coos bay
# Processing Record 37 of Set 15 | kununurra
# Processing Record 38 of Set 15 | sumenep
# Processing Record 39 of Set 15 | kingman
# Processing Record 40 of Set 15 | mitchell
# Processing Record 41 of Set 15 | taft
# Processing Record 42 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 43 of Set 15 | bergerac
# Processing Record 44 of Set 15 | sao jose de ribamar
# Processing Record 45 of Set 15 | polunochnoye
# Processing Record 46 of Set 15 | shieli
# Processing Record 47 of Set 15 | sawakin
# Processing Record 48 of Set 15 | krasnoturansk
# Processing Record 49 of Set 15 | saryagash
# Processing Record 50 of Set 15 | barcelos
# Processing Record 1 of Set 16 | waingapu
# Processing Record 2 of Set 16 | nsanje
# Processing Record 3 of Set 16 | maceio
# Processing Record 4 of Set 16 | ariogala
# Processing Record 5 of Set 16 | andenes
# Processing Record 6 of Set 16 | yanam
# Processing Record 7 of Set 16 | puri
# Processing Record 8 of Set 16 | hambantota
# Processing Record 9 of Set 16 | stoyba
# City not found. Skipping...
# Processing Record 10 of Set 16 | saint-joseph
# Processing Record 11 of Set 16 | fairbanks
# Processing Record 12 of Set 16 | kiama
# Processing Record 13 of Set 16 | hamilton
# Processing Record 14 of Set 16 | morondava
# Processing Record 15 of Set 16 | araouane
# Processing Record 16 of Set 16 | kayerkan
# Processing Record 17 of Set 16 | akalkot
# Processing Record 18 of Set 16 | sagua la grande
# Processing Record 19 of Set 16 | tilichiki
# Processing Record 20 of Set 16 | bontang
# Processing Record 21 of Set 16 | roseti
# Processing Record 22 of Set 16 | hirara
# Processing Record 23 of Set 16 | aksarka
# Processing Record 24 of Set 16 | ilebo
# Processing Record 25 of Set 16 | mulege
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Noumea -22.2763  166.4572     75.18        99           0
# 1   Capinopolis -18.6819  -49.5697     73.62        26           8
# 2      Khatanga  71.9667  102.5000     53.82        92         100
# 3       Kavieng  -2.5744  150.7967     82.56        77          98
# 4  Port Hedland -20.3167  118.5667     62.65       100          26
# 5       Ushuaia -54.8000  -68.3000     37.06        60          90
# 6         Kharp  66.8014   65.8081     51.40        78          44
# 7        Atuona  -9.8000 -139.0333     77.59        68          74
# 8         Lishu  43.3047  124.3278     78.87        78           7
# 9     Busselton -33.6500  115.3333     48.04        74          67
#
#    Wind Speed Country Current Description
# 0        9.71      NC           clear sky
# 1        4.03      BR           clear sky
# 2        2.08      RU     overcast clouds
# 3        8.05      PG          light rain
# 4        3.44      AU    scattered clouds
# 5        9.22      AR     overcast clouds
# 6        4.05      RU    scattered clouds
# 7       17.94      PF       broken clouds
# 8        6.69      CN           clear sky
# 9        7.43      AU       broken clouds

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Noumea      NC -22.2763  166.4572     75.18        99           0
# 1     Capinopolis      BR -18.6819  -49.5697     73.62        26           8
# 2        Khatanga      RU  71.9667  102.5000     53.82        92         100
# 3         Kavieng      PG  -2.5744  150.7967     82.56        77          98
# 4    Port Hedland      AU -20.3167  118.5667     62.65       100          26
# ..            ...     ...      ...       ...       ...       ...         ...
# 700        Roseti      RO  44.2167   27.4333     66.04        55           9
# 701        Hirara      JP  24.8000  125.2833     84.47        89          75
# 702       Aksarka      RU  66.5606   67.7975     50.32        91          14
# 703         Ilebo      CD  -4.3167   20.5833     73.94        38          11
# 704        Mulege      MX  26.8833 -111.9833     93.72        49          24
#
#      Wind Speed Current Description
# 0          9.71           clear sky
# 1          4.03           clear sky
# 2          2.08     overcast clouds
# 3          8.05          light rain
# 4          3.44    scattered clouds
# ..          ...                 ...
# 700        1.99           clear sky
# 701       32.21       moderate rain
# 702        3.00          few clouds
# 703        2.30          few clouds
# 704        8.77          few clouds
#
# [705 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
